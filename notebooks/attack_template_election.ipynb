# %% [markdown]
# # 多数決方式のテンプレート
#
# - GAOZの組みを全く変えていない場合に利用する
#   -> 多数決方式でせめる
#
# ## 派生方式
#
# ### election with ignorance
#
# 多数決をするが、候補が複数あり、合致しているものを採用する方式。
#
# ただし、NaNの数が多くなるので、ハミング距離が必然的に小さくなり、一見良さそうに見えるのに注意
#
# ### wegihted election
#
# 多数決をする際に、Reviewのカラムの長さが長い順に重みを大きくして、多数決を行う。
#
# MAEの性質上、カラム数が多い方が実際の値に全体的に近くなることが考えられるからである。
#
# ### 担当者と日付
# 2024/10/2 渡邉健

# %%
import pandas as pd
import numpy as np
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
# fmt: off
ALL_HEADER = ['Name', 'Gender', 'Age', 'Occupation', 'ZIP-code', '2', '56', '247', '260', '653', '673', '810', '885',  # noqa: E501
                      '1009', '1073', '1097', '1126', '1525', '1654', '1702', '1750', '1881', '1920', '1967', '2017',  # noqa: E501
                      '2021', '2043', '2086', '2087', '2093', '2100', '2105', '2138', '2143', '2174', '2193', '2253',  # noqa: E501
                      '2399', '2628', '2797', '2872', '2968', '3393', '3438', '3439', '3440', '3466', '3479', '3489',  # noqa: E501
                      '3877', '3889'] # noqa

B_HEADERS_LIST = [
  ['Gender', 'Age', 'Occupation', 'ZIP-code', '260', '653', '1525', '2105', '2193', '2253', '2628', '2872', '3438', '3439', '3440', '3877', '3889'],  # noqa: E501
  ['Gender', 'Age', 'Occupation', 'ZIP-code', '2', '56', '260', '653', '673', '1009', '1073', '1525', '1750', '1881', '1967', '2043', '2093', '2105', '2143', '2193', '2399', '2628', '2968', '3479', '3489', '3877', '3889'],  # noqa: E501
  ['Gender', 'Age', 'Occupation', 'ZIP-code', '673', '1881', '1920', '2087', '2138'],  # noqa: E501
  ['Gender', 'Age', 'Occupation', 'ZIP-code', '2', '56', '673', '810', '885', '1009', '1073', '1097', '1525', '1654', '1702', '1750', '1881', '1920', '1967', '2017', '2043', '2087', '2093', '2138', '2399', '3438', '3439', '3440'],  # noqa: E501
  ['Gender', 'Age', 'Occupation', 'ZIP-code', '673', '810', '1073', '1126', '1702', '2100', '2174', '2253', '2797', '3393', '3466'],  # noqa: E501
  ['Gender', 'Age', 'Occupation', 'ZIP-code', '247', '885', '1097', '1654', '2086', '2138', '2872'],  # noqa: E501
  ['Gender', 'Age', 'Occupation', 'ZIP-code', '247', '2100', '2143', '2872', '3479'],  # noqa: E501
  ['Gender', 'Age', 'Occupation', 'ZIP-code', '260', '1097', '1750', '2021', '2093', '2105', '2628', '2968'],  # noqa: E501
  ['Gender', 'Age', 'Occupation', 'ZIP-code', '247', '1920', '2017', '2087'],  # noqa: E501
  ['Gender', 'Age', 'Occupation', 'ZIP-code', '260', '1097', '2628', '2174', '2797', '1073', '2100', '2968', '2105', '2193'],  # noqa: E501
]

B_USER_ATTRIBUTE_HEADERS = ['Gender', 'Age', 'Occupation', 'ZIP-code']

B_REVIEW_HEADERS_LIST = [
  ['260', '653', '1525', '2105', '2193', '2253', '2628', '2872', '3438', '3439', '3440', '3877', '3889'],  # noqa: E501
  ['2', '56', '260', '653', '673', '1009', '1073', '1525', '1750', '1881', '1967', '2043', '2093', '2105', '2143', '2193', '2399', '2628', '2968', '3479', '3489', '3877', '3889'],  # noqa: E501
  ['673', '1881', '1920', '2087', '2138'],  # noqa: E501
  ['2', '56', '673', '810', '885', '1009', '1073', '1097', '1525', '1654', '1702', '1750', '1881', '1920', '1967', '2017', '2043', '2087', '2093', '2138', '2399', '3438', '3439', '3440'],  # noqa: E501
  ['673', '810', '1073', '1126', '1702', '2100', '2174', '2253', '2797', '3393', '3466'],  # noqa: E501
  ['247', '885', '1097', '1654', '2086', '2138', '2872'],  # noqa: E501
  ['247', '2100', '2143', '2872', '3479'],  # noqa: E501
  ['260', '1097', '1750', '2021', '2093', '2105', '2628', '2968'],  # noqa: E501
  ['247', '1920', '2017', '2087'],  # noqa: E501
  ['260', '1097', '2628', '2174', '2797', '1073', '2100', '2968', '2105', '2193'],  # noqa: E501
]

MOVIE_IDS = ['2', '56', '247', '260', '653', '673', '810', '885', '1009', '1073', '1097', '1126', '1525', '1654', '1702', '1750', '1881', '1920', '1967', '2017', '2021', '2043', '2086', '2087', '2093', '2100', '2105', '2138', '2143', '2174', '2193', '2253', '2399', '2628', '2797', '2872', '2968', '3393', '3438', '3439', '3440', '3466', '3479', '3489', '3877', '3889']
# fmt: on

# %% [markdown]
# ### C_0 ~ C_9までの読み込み

# %%
from os import listdir

ATTACK_TARGET = "21"

c_data_list = []

files = listdir("../data")

for i in range(10):
    c_data = pd.read_csv(f"../data/C{ATTACK_TARGET}_{i}.csv")
    file = None
    for f in files:
        if f.startswith(f"C{ATTACK_TARGET}_{i}"):
            file = f
            break
    if file is None:
        print(f)
        raise("File not found")
    c_data_list.append(c_data)

c_data_list[0]
# Out:
#      Gender  Age  Occupation  ZIP-code  260  653  1525  2105  2193  2253  \
# 0         F   18          12       136    0    0     0     0     0     0
# 1         F   25          17       967    0    4     3     2     0     0
# 2         F   18           6       445    0    0     0     4     1     0
# 3         M   50           5       523    0    0     0     5     2     1
# 4         M    1          17       321    3    4     4     3     4     1
# ...     ...  ...         ...       ...  ...  ...   ...   ...   ...   ...
# 9995      F   25           4       752    2    1     0     5     0     2
# 9996      M   18          13       532    3    2     0     5     2     4
# 9997      M   35           6       210    2    1     0     4     0     2
# 9998      M    1          12       494    4    2     4     5     1     3
# 9999      F   25           4       672    0    0     0     0     2     3
#
#       2628  2872  3438  3439  3440  3877  3889
# 0        4     0     2     0     0     0     0
# 1        4     4     1     0     1     0     0
# 2        2     0     0     2     3     4     0
# 3        2     2     3     0     0     0     5
# 4        0     3     3     5     0     0     5
# ...    ...   ...   ...   ...   ...   ...   ...
# 9995     4     0     0     1     3     0     0
# 9996     0     0     1     0     1     5     3
# 9997     5     5     2     2     0     0     3
# 9998     0     1     1     3     3     5     3
# 9999     1     4     3     2     0     5     2
#
# [10000 rows x 17 columns]

# %% [markdown]
# ### Ba, Bbの読み込み

# %%
Ba = pd.read_csv(f"../data/B{ATTACK_TARGET}a.csv", names=ALL_HEADER)
Ba = Ba.drop(0)
Ba.head()
# Out:
#               Name Gender Age Occupation ZIP-code   2  56  247  260  653  ...  \
# 1     Yank Schiell      M  50         16      104 NaN NaN  NaN  NaN  NaN  ...
# 2  Prince Tibbotts      M   1          4      132 NaN NaN  NaN  NaN  NaN  ...
# 3  Martainn Mellem      M  50         12      971 NaN NaN  NaN  NaN  NaN  ...
# 4    Dorey Pittson      M  50          0      954 NaN NaN  NaN  NaN  NaN  ...
# 5     Dav Wakeling      M  50         10      146 NaN NaN  NaN  NaN  NaN  ...
#
#    2968  3393  3438  3439  3440  3466  3479  3489  3877  3889
# 1   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 2   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 3   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 4   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 5   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [5 rows x 51 columns]

# %%
Bb = pd.read_csv(f"../data/B{ATTACK_TARGET}b.csv")
Bb.head()
# Out:
#    2 56  247 260 653 673 810 885 1009 1073  ...  2968  3393 3438  3439 3440  \
# 0  0  0    3   1   2   5   3   0    0    *  ...     1     0    4     3    0
# 1  5  3    4   4   0   0   0   0    5    1  ...     0     0    0     0    0
# 2  0  1    5   2   0   3   0   0    0    1  ...     0     3    2     0    0
# 3  4  3    4   1   0   2   0   3    *    4  ...     1     4    5     1    2
# 4  0  4    5   2   5   5   0   4    0    2  ...     0     0    2     0    0
#
#   3466 3479  3489 3877  3889
# 0    0    0     2    0     4
# 1    0    4     2    0     0
# 2    0    4     1    0     1
# 3    4    5     0    0     4
# 4    0    3     3    0     1
#
# [5 rows x 46 columns]

# %% [markdown]
# ### BaのN番目の行と完全一致する行をC0~C9から取得

# %%
# Baの2行目を選択
row_index = 2

gender = Ba.iloc[row_index]["Gender"]
age = Ba.iloc[row_index]["Age"]
occupation = Ba.iloc[row_index]["Occupation"]
zipcode = Ba.iloc[row_index]["ZIP-code"]

print("検索条件")
print(gender, age, occupation, zipcode)

filtered_C_list = []

# 完全一致を見つける
for c in c_data_list:
    filtered_C_0 = c[(c['Gender'] == gender) & 
                      (c['Age'] == int(age)) & 
                      (c['Occupation'] == int(occupation)) & 
                      (c['ZIP-code'] == int(zipcode))]
    filtered_C_list.append(filtered_C_0)

print("完全一致した件数 (10であることが望まれる)")
print(len(filtered_C_list))
# Out:
# 検索条件
# M 50 12 971
# 完全一致した件数 (10であることが望まれる)
# 10

# %% [markdown]
# ### 各カラムごとに多数決の候補を表示する

# %%
merged_rows = []

for i, filtered_df in enumerate(filtered_C_list):
    if not filtered_df.empty:
        # 各フィルタリングされたデータフレームから1行だけ取得
        row = filtered_df.iloc[0]
        
        # ALL_HEADERに基づいて新しい行を作成
        new_row = pd.Series(index=ALL_HEADER)
        
        # データを転送
        for col in ALL_HEADER:
            if col in filtered_df.columns:
                new_row[col] = row[col]
            else:
                new_row[col] = np.nan
        
        # 新しい行をリストに追加
        merged_rows.append(new_row)

# リストからデータフレームを作成
merged_df = pd.DataFrame(merged_rows, columns=ALL_HEADER)
merged_df
# Out:
# Empty DataFrame
# Columns: [Name, Gender, Age, Occupation, ZIP-code, 2, 56, 247, 260, 653, 673, 810, 885, 1009, 1073, 1097, 1126, 1525, 1654, 1702, 1750, 1881, 1920, 1967, 2017, 2021, 2043, 2086, 2087, 2093, 2100, 2105, 2138, 2143, 2174, 2193, 2253, 2399, 2628, 2797, 2872, 2968, 3393, 3438, 3439, 3440, 3466, 3479, 3489, 3877, 3889]
# Index: []
#
# [0 rows x 51 columns]

# %% [markdown]
# ### ざっと見て、多数決の候補にばらつきはなさそうと判断し、各行に対してランダムに一つ値を取得できるようにする

# %%
def select_random_value(column):
    # NaNを除外した値のリストを作成
    valid_values = column.dropna().tolist()
    if valid_values:
        # 有効な値がある場合、ランダムに1つ選択
        return np.random.choice(valid_values)
    else:
        # 有効な値がない場合はNaNを返す
        return np.nan

# 各カラムからランダムに値を選択
random_values = {}
for column in merged_df.columns:
    random_values[column] = select_random_value(merged_df[column])

# 結果を新しいデータフレームとして作成
result_df = pd.DataFrame([random_values])
result_df
# Out:
#    Name  Gender  Age  Occupation  ZIP-code   2  56  247  260  653  ...  2968  \
# 0   NaN     NaN  NaN         NaN       NaN NaN NaN  NaN  NaN  NaN  ...   NaN
#
#    3393  3438  3439  3440  3466  3479  3489  3877  3889
# 0   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [1 rows x 51 columns]

# %% [markdown]
# ### 以上の処理をBaの各行（0~49行）に対して実行する

# %%
import pandas as pd
import numpy as np

final_df = pd.DataFrame(columns=ALL_HEADER)

for row_index in range(50):
    # Baデータフレームから現在の行の情報を取得
    gender = Ba.iloc[row_index]["Gender"]
    age = Ba.iloc[row_index]["Age"]
    occupation = Ba.iloc[row_index]["Occupation"]
    zipcode = Ba.iloc[row_index]["ZIP-code"]

    filtered_C_list = []

    # 各cデータフレームに対して、完全一致するレコードをフィルタリング
    for c in c_data_list:
        filtered_C_0 = c[(c['Gender'] == gender) & 
                        (c['Age'] == int(age)) & 
                        (c['Occupation'] == int(occupation)) & 
                        (c['ZIP-code'] == int(zipcode))]
        filtered_C_list.append(filtered_C_0)

    # 多数決の候補となる行のリストを作成
    candidate_rows = []
    for i, filtered_df in enumerate(filtered_C_list):
        if not filtered_df.empty:
            # 各フィルタリングされたデータフレームから1行だけ取得
            row = filtered_df.iloc[0]
            # ALL_HEADERに基づいて新しい行を作成し、データを転送
            candidate_row = pd.Series(index=ALL_HEADER)
            for col in ALL_HEADER:
                candidate_row[col] = row[col] if col in filtered_df.columns else np.nan
            # 新しい行を候補リストに追加
            candidate_rows.append(candidate_row)

    # 候補行のリストからデータフレームを作成
    candidate_rows_df = pd.DataFrame(candidate_rows, columns=ALL_HEADER)

    # 各列に対して、ランダムに値を選択（多数決の実装）
    elected_value = {}
    for column in ALL_HEADER:
        elected_value[column] = select_random_value(candidate_rows_df[column])

    # 選択された値から新しい行を作成
    elected_value_row_df = pd.DataFrame([elected_value])

    # 選択された行をfinal_dfの最後に追加
    final_df = pd.concat([final_df, elected_value_row_df], ignore_index=True)

final_df
# Out:
#    Name Gender  Age Occupation ZIP-code    2   56  247  260  653  ...  2968  \
# 0   NaN    NaN  NaN        NaN      NaN  NaN  NaN  NaN  NaN  NaN  ...   NaN
# 1   NaN      M    1          4      132  0.0  1.0  4.0  NaN  NaN  ...   NaN
# 2   NaN    NaN  NaN        NaN      NaN  NaN  NaN  NaN  NaN  NaN  ...   NaN
# 3   NaN      M   50          0      954  NaN  NaN  NaN  4.0  0.0  ...   0.0
# 4   NaN    NaN  NaN        NaN      NaN  NaN  NaN  NaN  NaN  NaN  ...   NaN
# 5   NaN    NaN  NaN        NaN      NaN  NaN  NaN  NaN  NaN  NaN  ...   NaN
# 6   NaN      F    1         10      919  NaN  NaN  4.0  NaN  NaN  ...   NaN
# 7   NaN      F   25         18       26  NaN  NaN  4.0  NaN  NaN  ...   NaN
# 8   NaN    NaN  NaN        NaN      NaN  NaN  NaN  NaN  NaN  NaN  ...   NaN
# 9   NaN    NaN  NaN        NaN      NaN  NaN  NaN  NaN  NaN  NaN  ...   NaN
# 10  NaN      M   25          3       85  NaN  NaN  NaN  1.0  0.0  ...   NaN
# 11  NaN      M   35          4      975  NaN  NaN  NaN  NaN  NaN  ...   NaN
# 12  NaN      F   18         12      914  NaN  NaN  0.0  NaN  NaN  ...   NaN
# 13  NaN      F   50          4      919  NaN  NaN  NaN  NaN  NaN  ...   NaN
# 14  NaN      M   25          8      609  NaN  NaN  NaN  2.0  NaN  ...   0.0
# 15  NaN    NaN  NaN        NaN      NaN  NaN  NaN  NaN  NaN  NaN  ...   NaN
# 16  NaN      F   18         16      799  NaN  NaN  5.0  NaN  NaN  ...   NaN
# 17  NaN      F   35          2      486  NaN  NaN  3.0  1.0  NaN  ...   2.0
# 18  NaN    NaN  NaN        NaN      NaN  NaN  NaN  NaN  NaN  NaN  ...   NaN
# 19  NaN    NaN  NaN        NaN      NaN  NaN  NaN  NaN  NaN  NaN  ...   NaN
# 20  NaN      M   50          0      602  NaN  NaN  0.0  NaN  NaN  ...   NaN
# 21  NaN    NaN  NaN        NaN      NaN  NaN  NaN  NaN  NaN  NaN  ...   NaN
# 22  NaN    NaN  NaN        NaN      NaN  NaN  NaN  NaN  NaN  NaN  ...   NaN
# 23  NaN      M   25          2      230  NaN  NaN  3.0  NaN  NaN  ...   NaN
# 24  NaN    NaN  NaN        NaN      NaN  NaN  NaN  NaN  NaN  NaN  ...   NaN
# 25  NaN      M    1          0      735  1.0  0.0  NaN  NaN  NaN  ...   NaN
# 26  NaN    NaN  NaN        NaN      NaN  NaN  NaN  NaN  NaN  NaN  ...   NaN
# 27  NaN    NaN  NaN        NaN      NaN  NaN  NaN  NaN  NaN  NaN  ...   NaN
# 28  NaN      F    1          4       48  4.0  0.0  NaN  5.0  NaN  ...   4.0
# 29  NaN      M   45          3      141  5.0  3.0  0.0  4.0  0.0  ...   0.0
# 30  NaN      F   25         19      181  NaN  NaN  NaN  0.0  NaN  ...   0.0
# 31  NaN      F   50          2      863  4.0  1.0  NaN  5.0  2.0  ...   4.0
# 32  NaN    NaN  NaN        NaN      NaN  NaN  NaN  NaN  NaN  NaN  ...   NaN
# 33  NaN    NaN  NaN        NaN      NaN  NaN  NaN  NaN  NaN  NaN  ...   NaN
# 34  NaN      M   25          8      701  NaN  NaN  NaN  0.0  5.0  ...   NaN
# 35  NaN      M   25          2      850  4.0  4.0  NaN  4.0  0.0  ...   5.0
# 36  NaN    NaN  NaN        NaN      NaN  NaN  NaN  NaN  NaN  NaN  ...   NaN
# 37  NaN      F    1         17      430  5.0  4.0  NaN  5.0  2.0  ...   5.0
# 38  NaN      F   45         15      629  NaN  NaN  3.0  NaN  NaN  ...   NaN
# 39  NaN    NaN  NaN        NaN      NaN  NaN  NaN  NaN  NaN  NaN  ...   NaN
# 40  NaN    NaN  NaN        NaN      NaN  NaN  NaN  NaN  NaN  NaN  ...   NaN
# 41  NaN    NaN  NaN        NaN      NaN  NaN  NaN  NaN  NaN  NaN  ...   NaN
# 42  NaN      M    1          0      109  0.0  0.0  NaN  4.0  0.0  ...   3.0
# 43  NaN    NaN  NaN        NaN      NaN  NaN  NaN  NaN  NaN  NaN  ...   NaN
# 44  NaN      F   25         12      993  5.0  3.0  NaN  NaN  NaN  ...   NaN
# 45  NaN      M   35         17      320  NaN  NaN  NaN  3.0  NaN  ...   4.0
# 46  NaN    NaN  NaN        NaN      NaN  NaN  NaN  NaN  NaN  NaN  ...   NaN
# 47  NaN    NaN  NaN        NaN      NaN  NaN  NaN  NaN  NaN  NaN  ...   NaN
# 48  NaN      M   50          5      640  NaN  NaN  5.0  NaN  NaN  ...   NaN
# 49  NaN    NaN  NaN        NaN      NaN  NaN  NaN  NaN  NaN  NaN  ...   NaN
#
#     3393 3438  3439  3440 3466  3479  3489 3877  3889
# 0    NaN  NaN   NaN   NaN  NaN   NaN   NaN  NaN   NaN
# 1    NaN  5.0   0.0   0.0  NaN   NaN   NaN  NaN   NaN
# 2    NaN  NaN   NaN   NaN  NaN   NaN   NaN  NaN   NaN
# 3    NaN  2.0   0.0   0.0  NaN   NaN   NaN  0.0   5.0
# 4    NaN  NaN   NaN   NaN  NaN   NaN   NaN  NaN   NaN
# 5    NaN  NaN   NaN   NaN  NaN   NaN   NaN  NaN   NaN
# 6    3.0  NaN   NaN   NaN  3.0   NaN   NaN  NaN   NaN
# 7    NaN  NaN   NaN   NaN  NaN   NaN   NaN  NaN   NaN
# 8    NaN  NaN   NaN   NaN  NaN   NaN   NaN  NaN   NaN
# 9    NaN  NaN   NaN   NaN  NaN   NaN   NaN  NaN   NaN
# 10   NaN  4.0   3.0   0.0  NaN   NaN   NaN  0.0   0.0
# 11   0.0  NaN   NaN   NaN  0.0   NaN   NaN  NaN   NaN
# 12   NaN  NaN   NaN   NaN  NaN   5.0   NaN  NaN   NaN
# 13   0.0  NaN   NaN   NaN  0.0   NaN   NaN  NaN   NaN
# 14   0.0  NaN   NaN   NaN  5.0   NaN   NaN  NaN   NaN
# 15   NaN  NaN   NaN   NaN  NaN   NaN   NaN  NaN   NaN
# 16   NaN  NaN   NaN   NaN  NaN   5.0   NaN  NaN   NaN
# 17   NaN  NaN   NaN   NaN  NaN   5.0   NaN  NaN   NaN
# 18   NaN  NaN   NaN   NaN  NaN   NaN   NaN  NaN   NaN
# 19   NaN  NaN   NaN   NaN  NaN   NaN   NaN  NaN   NaN
# 20   NaN  NaN   NaN   NaN  NaN   NaN   NaN  NaN   NaN
# 21   NaN  NaN   NaN   NaN  NaN   NaN   NaN  NaN   NaN
# 22   NaN  NaN   NaN   NaN  NaN   NaN   NaN  NaN   NaN
# 23   NaN  NaN   NaN   NaN  NaN   4.0   NaN  NaN   NaN
# 24   NaN  NaN   NaN   NaN  NaN   NaN   NaN  NaN   NaN
# 25   NaN  3.0   3.0   0.0  NaN   NaN   NaN  NaN   NaN
# 26   NaN  NaN   NaN   NaN  NaN   NaN   NaN  NaN   NaN
# 27   NaN  NaN   NaN   NaN  NaN   NaN   NaN  NaN   NaN
# 28   NaN  3.0   0.0   0.0  NaN   NaN   NaN  NaN   NaN
# 29   NaN  NaN   NaN   NaN  NaN   0.0   0.0  3.0   2.0
# 30   NaN  NaN   NaN   NaN  NaN   NaN   NaN  NaN   NaN
# 31   NaN  1.0   3.0   3.0  NaN   NaN   NaN  2.0   2.0
# 32   NaN  NaN   NaN   NaN  NaN   NaN   NaN  NaN   NaN
# 33   NaN  NaN   NaN   NaN  NaN   NaN   NaN  NaN   NaN
# 34   NaN  0.0   0.0   0.0  NaN   NaN   NaN  1.0   3.0
# 35   NaN  4.0   0.0   1.0  NaN   3.0   4.0  3.0   4.0
# 36   NaN  NaN   NaN   NaN  NaN   NaN   NaN  NaN   NaN
# 37   NaN  NaN   NaN   NaN  NaN   4.0   0.0  3.0   1.0
# 38   NaN  NaN   NaN   NaN  NaN   NaN   NaN  NaN   NaN
# 39   NaN  NaN   NaN   NaN  NaN   NaN   NaN  NaN   NaN
# 40   NaN  NaN   NaN   NaN  NaN   NaN   NaN  NaN   NaN
# 41   NaN  NaN   NaN   NaN  NaN   NaN   NaN  NaN   NaN
# 42   NaN  NaN   NaN   NaN  NaN   3.0   4.0  0.0   0.0
# 43   NaN  NaN   NaN   NaN  NaN   NaN   NaN  NaN   NaN
# 44   NaN  2.0   2.0   0.0  NaN   NaN   NaN  NaN   NaN
# 45   NaN  NaN   NaN   NaN  NaN   NaN   NaN  NaN   NaN
# 46   NaN  NaN   NaN   NaN  NaN   NaN   NaN  NaN   NaN
# 47   NaN  NaN   NaN   NaN  NaN   NaN   NaN  NaN   NaN
# 48   NaN  NaN   NaN   NaN  NaN   NaN   NaN  NaN   NaN
# 49   NaN  NaN   NaN   NaN  NaN   NaN   NaN  NaN   NaN
#
# [50 rows x 51 columns]

# %% [markdown]
# ### 最終的に得た映画のレビューの候補とBbを比較し、Bbの何番目のindexが一番近くてハミング距離にどれくらいの違いがあるかを取得する

# %%
def hamming_distance(a, b):
    a_int = a.fillna(0).astype(int)
    b_int = b.replace('*', None).fillna(0).astype(int)
    # ハミング距離の計算
    return np.sum(a_int != b_int)

def find_closest_row(row, Bb):
    distances = Bb.apply(lambda bb_row: hamming_distance(row[MOVIE_IDS], bb_row[MOVIE_IDS]), axis=1)
    min_distance = distances.min()
    closest_index = distances.idxmin()
    return pd.Series({'Min_Hamming_Distance': min_distance, 'Closest_Bb_Index': closest_index})

# 結果を格納するデータフレーム
result_df = pd.DataFrame(index=final_df.index, columns=['Min_Hamming_Distance', 'Closest_Bb_Index'])

# 各行に対してハミング距離を計算し、最も近い行を見つける
for idx, row in final_df[MOVIE_IDS].iterrows():
    result = find_closest_row(row, Bb[MOVIE_IDS])
    result_df.loc[idx] = result

# 元のfinal_dfにハミング距離の結果を結合
final_result_df = pd.concat([final_df, result_df], axis=1)
final_result_df
# Out:
#    Name Gender  Age Occupation ZIP-code    2   56  247  260  653  ...  3438  \
# 0   NaN    NaN  NaN        NaN      NaN  NaN  NaN  NaN  NaN  NaN  ...   NaN
# 1   NaN      M    1          4      132  0.0  1.0  4.0  NaN  NaN  ...   5.0
# 2   NaN    NaN  NaN        NaN      NaN  NaN  NaN  NaN  NaN  NaN  ...   NaN
# 3   NaN      M   50          0      954  NaN  NaN  NaN  4.0  0.0  ...   2.0
# 4   NaN    NaN  NaN        NaN      NaN  NaN  NaN  NaN  NaN  NaN  ...   NaN
# 5   NaN    NaN  NaN        NaN      NaN  NaN  NaN  NaN  NaN  NaN  ...   NaN
# 6   NaN      F    1         10      919  NaN  NaN  4.0  NaN  NaN  ...   NaN
# 7   NaN      F   25         18       26  NaN  NaN  4.0  NaN  NaN  ...   NaN
# 8   NaN    NaN  NaN        NaN      NaN  NaN  NaN  NaN  NaN  NaN  ...   NaN
# 9   NaN    NaN  NaN        NaN      NaN  NaN  NaN  NaN  NaN  NaN  ...   NaN
# 10  NaN      M   25          3       85  NaN  NaN  NaN  1.0  0.0  ...   4.0
# 11  NaN      M   35          4      975  NaN  NaN  NaN  NaN  NaN  ...   NaN
# 12  NaN      F   18         12      914  NaN  NaN  0.0  NaN  NaN  ...   NaN
# 13  NaN      F   50          4      919  NaN  NaN  NaN  NaN  NaN  ...   NaN
# 14  NaN      M   25          8      609  NaN  NaN  NaN  2.0  NaN  ...   NaN
# 15  NaN    NaN  NaN        NaN      NaN  NaN  NaN  NaN  NaN  NaN  ...   NaN
# 16  NaN      F   18         16      799  NaN  NaN  5.0  NaN  NaN  ...   NaN
# 17  NaN      F   35          2      486  NaN  NaN  3.0  1.0  NaN  ...   NaN
# 18  NaN    NaN  NaN        NaN      NaN  NaN  NaN  NaN  NaN  NaN  ...   NaN
# 19  NaN    NaN  NaN        NaN      NaN  NaN  NaN  NaN  NaN  NaN  ...   NaN
# 20  NaN      M   50          0      602  NaN  NaN  0.0  NaN  NaN  ...   NaN
# 21  NaN    NaN  NaN        NaN      NaN  NaN  NaN  NaN  NaN  NaN  ...   NaN
# 22  NaN    NaN  NaN        NaN      NaN  NaN  NaN  NaN  NaN  NaN  ...   NaN
# 23  NaN      M   25          2      230  NaN  NaN  3.0  NaN  NaN  ...   NaN
# 24  NaN    NaN  NaN        NaN      NaN  NaN  NaN  NaN  NaN  NaN  ...   NaN
# 25  NaN      M    1          0      735  1.0  0.0  NaN  NaN  NaN  ...   3.0
# 26  NaN    NaN  NaN        NaN      NaN  NaN  NaN  NaN  NaN  NaN  ...   NaN
# 27  NaN    NaN  NaN        NaN      NaN  NaN  NaN  NaN  NaN  NaN  ...   NaN
# 28  NaN      F    1          4       48  4.0  0.0  NaN  5.0  NaN  ...   3.0
# 29  NaN      M   45          3      141  5.0  3.0  0.0  4.0  0.0  ...   NaN
# 30  NaN      F   25         19      181  NaN  NaN  NaN  0.0  NaN  ...   NaN
# 31  NaN      F   50          2      863  4.0  1.0  NaN  5.0  2.0  ...   1.0
# 32  NaN    NaN  NaN        NaN      NaN  NaN  NaN  NaN  NaN  NaN  ...   NaN
# 33  NaN    NaN  NaN        NaN      NaN  NaN  NaN  NaN  NaN  NaN  ...   NaN
# 34  NaN      M   25          8      701  NaN  NaN  NaN  0.0  5.0  ...   0.0
# 35  NaN      M   25          2      850  4.0  4.0  NaN  4.0  0.0  ...   4.0
# 36  NaN    NaN  NaN        NaN      NaN  NaN  NaN  NaN  NaN  NaN  ...   NaN
# 37  NaN      F    1         17      430  5.0  4.0  NaN  5.0  2.0  ...   NaN
# 38  NaN      F   45         15      629  NaN  NaN  3.0  NaN  NaN  ...   NaN
# 39  NaN    NaN  NaN        NaN      NaN  NaN  NaN  NaN  NaN  NaN  ...   NaN
# 40  NaN    NaN  NaN        NaN      NaN  NaN  NaN  NaN  NaN  NaN  ...   NaN
# 41  NaN    NaN  NaN        NaN      NaN  NaN  NaN  NaN  NaN  NaN  ...   NaN
# 42  NaN      M    1          0      109  0.0  0.0  NaN  4.0  0.0  ...   NaN
# 43  NaN    NaN  NaN        NaN      NaN  NaN  NaN  NaN  NaN  NaN  ...   NaN
# 44  NaN      F   25         12      993  5.0  3.0  NaN  NaN  NaN  ...   2.0
# 45  NaN      M   35         17      320  NaN  NaN  NaN  3.0  NaN  ...   NaN
# 46  NaN    NaN  NaN        NaN      NaN  NaN  NaN  NaN  NaN  NaN  ...   NaN
# 47  NaN    NaN  NaN        NaN      NaN  NaN  NaN  NaN  NaN  NaN  ...   NaN
# 48  NaN      M   50          5      640  NaN  NaN  5.0  NaN  NaN  ...   NaN
# 49  NaN    NaN  NaN        NaN      NaN  NaN  NaN  NaN  NaN  NaN  ...   NaN
#
#     3439 3440  3466  3479 3489  3877  3889 Min_Hamming_Distance  \
# 0    NaN  NaN   NaN   NaN  NaN   NaN   NaN                   16
# 1    0.0  0.0   NaN   NaN  NaN   NaN   NaN                   22
# 2    NaN  NaN   NaN   NaN  NaN   NaN   NaN                   16
# 3    0.0  0.0   NaN   NaN  NaN   0.0   5.0                   16
# 4    NaN  NaN   NaN   NaN  NaN   NaN   NaN                   16
# 5    NaN  NaN   NaN   NaN  NaN   NaN   NaN                   16
# 6    NaN  NaN   3.0   NaN  NaN   NaN   NaN                   21
# 7    NaN  NaN   NaN   NaN  NaN   NaN   NaN                   16
# 8    NaN  NaN   NaN   NaN  NaN   NaN   NaN                   16
# 9    NaN  NaN   NaN   NaN  NaN   NaN   NaN                   16
# 10   3.0  0.0   NaN   NaN  NaN   0.0   0.0                   15
# 11   NaN  NaN   0.0   NaN  NaN   NaN   NaN                   18
# 12   NaN  NaN   NaN   5.0  NaN   NaN   NaN                   18
# 13   NaN  NaN   0.0   NaN  NaN   NaN   NaN                   19
# 14   NaN  NaN   5.0   NaN  NaN   NaN   NaN                   21
# 15   NaN  NaN   NaN   NaN  NaN   NaN   NaN                   16
# 16   NaN  NaN   NaN   5.0  NaN   NaN   NaN                   17
# 17   NaN  NaN   NaN   5.0  NaN   NaN   NaN                   18
# 18   NaN  NaN   NaN   NaN  NaN   NaN   NaN                   16
# 19   NaN  NaN   NaN   NaN  NaN   NaN   NaN                   16
# 20   NaN  NaN   NaN   NaN  NaN   NaN   NaN                   17
# 21   NaN  NaN   NaN   NaN  NaN   NaN   NaN                   16
# 22   NaN  NaN   NaN   NaN  NaN   NaN   NaN                   16
# 23   NaN  NaN   NaN   4.0  NaN   NaN   NaN                   17
# 24   NaN  NaN   NaN   NaN  NaN   NaN   NaN                   16
# 25   3.0  0.0   NaN   NaN  NaN   NaN   NaN                   21
# 26   NaN  NaN   NaN   NaN  NaN   NaN   NaN                   16
# 27   NaN  NaN   NaN   NaN  NaN   NaN   NaN                   16
# 28   0.0  0.0   NaN   NaN  NaN   NaN   NaN                   20
# 29   NaN  NaN   NaN   0.0  0.0   3.0   2.0                   23
# 30   NaN  NaN   NaN   NaN  NaN   NaN   NaN                   16
# 31   3.0  3.0   NaN   NaN  NaN   2.0   2.0                   24
# 32   NaN  NaN   NaN   NaN  NaN   NaN   NaN                   16
# 33   NaN  NaN   NaN   NaN  NaN   NaN   NaN                   16
# 34   0.0  0.0   NaN   NaN  NaN   1.0   3.0                   18
# 35   0.0  1.0   NaN   3.0  4.0   3.0   4.0                   22
# 36   NaN  NaN   NaN   NaN  NaN   NaN   NaN                   16
# 37   NaN  NaN   NaN   4.0  0.0   3.0   1.0                   22
# 38   NaN  NaN   NaN   NaN  NaN   NaN   NaN                   15
# 39   NaN  NaN   NaN   NaN  NaN   NaN   NaN                   16
# 40   NaN  NaN   NaN   NaN  NaN   NaN   NaN                   16
# 41   NaN  NaN   NaN   NaN  NaN   NaN   NaN                   16
# 42   NaN  NaN   NaN   3.0  4.0   0.0   0.0                   21
# 43   NaN  NaN   NaN   NaN  NaN   NaN   NaN                   16
# 44   2.0  0.0   NaN   NaN  NaN   NaN   NaN                   22
# 45   NaN  NaN   NaN   NaN  NaN   NaN   NaN                   15
# 46   NaN  NaN   NaN   NaN  NaN   NaN   NaN                   16
# 47   NaN  NaN   NaN   NaN  NaN   NaN   NaN                   16
# 48   NaN  NaN   NaN   NaN  NaN   NaN   NaN                   15
# 49   NaN  NaN   NaN   NaN  NaN   NaN   NaN                   16
#
#     Closest_Bb_Index
# 0                 17
# 1                 24
# 2                 17
# 3                 34
# 4                 17
# 5                 17
# 6                 24
# 7                 24
# 8                 17
# 9                 17
# 10                24
# 11                17
# 12                24
# 13                34
# 14                45
# 15                17
# 16                17
# 17                24
# 18                17
# 19                17
# 20                24
# 21                17
# 22                17
# 23                24
# 24                17
# 25                45
# 26                17
# 27                17
# 28                34
# 29                45
# 30                17
# 31                37
# 32                17
# 33                17
# 34                45
# 35                24
# 36                17
# 37                33
# 38                24
# 39                17
# 40                17
# 41                17
# 42                24
# 43                17
# 44                 1
# 45                45
# 46                17
# 47                17
# 48                17
# 49                17
#
# [50 rows x 53 columns]
